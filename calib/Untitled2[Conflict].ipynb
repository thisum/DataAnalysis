# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.ma as ma

# N = 3
N = 5
weights = np.ones(N) / N
n = np.array([2764388, 2768326, 2768326, 2777445, 2777445, 2767066, 2755749, 2755749, 2753612, 2743201, 2735501, 2738142, 2738142, 2712718, 2697750, 2693262, 2697138, 2697138, 2836994, 2972007, 2808043, 2772405, 2772405, 2686322, 2641794, 2664938, 2678521, 2678521, 2678078, 2670512, 2669719, 2668846, 2668846, 2664833, 2662449, 2661292, 2661820, 2661820])
n2 = np.array([2697509, 2697039, 2696580, 2696580, 2696253, 2695997, 2695956, 2695183, 2695183, 2693557, 2692440, 2693000, 2694118, 2694118, 2695859, 2696541, 2697406, 2697731, 2697731, 2696042, 2691268, 2686077, 2682437, 2682437, 2683738, 2688837, 2693616, 2696811, 2696811, 2699863, 2701713, 2703137, 2703984, 2703984, 2704036, 2703261, 2702556, 2702033, 2702033, 2701538, 2701290])
n3 = np.array([2800619, 2798706, 2797183, 2797183, 2796377, 2795752, 2795173, 2794580, 2794580, 2794417, 2794405, 2794613, 2795073, 2795073, 2795647, 2795769, 2796759, 2797145, 2797145, 2796416, 2794937, 2793928, 2793579, 2793579, 2793125, 2791804, 2789777, 2788496, 2788496, 2787646, 2786967, 2788032, 2790794, 2790794, 2792856, 2794795, 2796388, 2798237, 2798237, 2798900, 2798398, 2796927, 2795858, 2795858])
n4 = np.array([2677249, 2677401, 2677560, 2677894, 2678042, 2678042, 2678344, 2678499, 2678418, 2678103, 2678103, 2678218, 2678160, 2677860, 2677494, 2677494, 2677653, 2677566, 2676821, 2676821, 2676987, 2677094, 2677589, 2678100, 2678599, 2678599, 2678807, 2679292, 2679778, 2680157, 2680157, 2680551, 2680410, 2680269, 2680269, 2680376])
n5 = np.array([2097229, 2097091, 2097117, 2097184, 2097184, 2097115, 2097063, 2097119, 2097122, 2097122, 2097158, 2097253, 2097147, 2097202, 2097202, 2097103, 2097167, 2097110, 2097167, 2097167, 2097101, 2097175, 2097115, 2097177, 2097177, 2097124, 2097191, 2097208, 2097249, 2097249, 2097101, 2097206, 2097202, 2097122, 2097122])
# weights = np.ones(N) / N
# np.convolve(n, weights, mode='valid')

# t = np.arange(0.0, 2.0, 0.01)
# s1 = np.sin(2*np.pi*t)
# s2 = np.sin(4*np.pi*t)

avg = np.convolve(n, weights, mode='valid')
x = np.arange(avg.size)
grad = np.gradient(avg, x)
plt.figure(1)
plt.plot(n)
# plt.plot(n2)
# plt.plot(n3)
# plt.plot(n4)
# plt.plot(n5)
plt.show()

# plt.plot(n2)
# plt.show()

# plt.subplot(212)
# plt.plot(n2)

# plt.subplot(313)
# plt.plot(n3)
# plt.show()
# plt.plot(n4)


# plt.show()
# plt.subplot(222)
# plt.plot(t, 2*s1)

# plt.figure(2)
# plt.plot(t, s2)

# %%
plt.show()
