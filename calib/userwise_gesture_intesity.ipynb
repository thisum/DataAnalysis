# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file = open("../gear_user_data/beverly_raw_data.txt","r")
lines = file.readlines()
data = {}
for line in lines:
    [l,d] = line.split(":")
    d = d.replace('[', '').replace(']', '').replace('\n', '')
    d = np.fromstring(d, dtype=int, sep=',')
    data.update({l:d})

# %%
lengths = []
N = 10
weights = np.ones(N) / N
plt.figure(num=1, figsize=(16, 16))
for key, value in data.items():
    if 'WT-SO' in key:
        lengths.append(value.size)
        avg = np.convolve(value, weights, mode='valid')
        x = np.arange(value.size)
        grad = np.gradient(value, x)
        print(np.amax(grad))
        plt.plot(grad)
        plt.title(key)
        
# plt.show()   
print(np.amax(lengths))
# Out:
# 93

# %%
length = []
for root, dirs, files in os.walk("../gear_user_data/"):
    for i, filename in enumerate(files):
#         print(filename)
        file = open(root + "/" + filename, "r")
        lines = file.readlines()
        for line in lines:
            [l, d] = line.split(":")
            if 'T3-HR' in l:
                d = d.replace('[', '').replace(']', '').replace('\n', '')
                d = np.fromstring(d, dtype=int, sep=',')
                length.append(d.size)
                
print(length)
plt.hist(length, 20)
#                 avg = np.convolve(d, weights, mode='valid')
#                 x = np.arange(d.size)
#                 grad = np.gradient(d, x)
#                 print(np.amax(grad))
#                 print('min: ' + str(np.amin(grad)) + '  max:' + str(np.amax(grad)))

# %%
hard = []
soft = []
mild = []
weights = np.ones(5) / 5
file = open("../gear_user_data/haimo_raw_data.txt","r")
lines = file.readlines()
for line in lines:
    [l,d] = line.split(":")
    d = d.replace('[', '').replace(']', '').replace('\n', '')
    d = np.fromstring(d, dtype=int, sep=',')
    data = np.convolve(d, weights, mode='valid')
    x = np.arange(data.size)
    grad = np.gradient(data, x)
    grad2 = np.gradient(grad, x)
    l = l.split("-")[1]
    if l == 'HR':        
        n_min = data.argmin()
        plt.figure(num=1, figsize=(16, 6))
        plt.subplot(1, 3, 1)
        plt.plot(grad2)
        plt.plot(grad)
#         plt.plot(x[n_min],grad[n_min],'o')
#         print(grad[n_min])
#         print(grad[n_min+1])
#         print(data[n_min])
#         print(data[n_min+1])
        
        glob_min = 1000000000
        crop_ary = np.array([])
        index  = 0
        for i in range(len(grad)-1):
            if grad[i] < 0 and grad[i+1] > 0:
                if glob_min == 1000000000:
                    crop_ary = data[:i+1]
                    glob_min = np.amin(crop_ary)
                elif np.amin(data[:i + 1]) < glob_min:
                    crop_ary = data[:i + 1]
#                 if glob_min == 1000000000 :
#                     crop_ary = data[:i+1]
#                     glob_min = 
                
                
                
#                 plt.plot(x[i],grad[i],'o')
#                 plt.plot(x[i+1],grad[i+1],'o')
#                 min_point = np.amin(data[:i])
#                 if min_point < glob_min:
#                     crop_ary = data[:i+1]
#                     glob_min = min_point
#                     index = i
                    
#                 min_point = np.amin(data[:i+1])
#                 if min_point < glob_min:
#                     crop_ary = data[:i+1]
#                     glob_min = min_point
#                     index = i
#                 print(str(glob_min) + "-" + str(min_point))
#             print(data[i])
#             print(data[i+1])
#         print(data)
#         print(data[:n_min+2])
        print('global min: ' + str(glob_min) + ' index: ' + str(index))
        plt.subplot(1, 3, 2)
        plt.plot(x,data)
        plt.plot(x[n_min],data[n_min],'o')
        
        plt.subplot(1, 3, 3)
        plt.plot(crop_ary)
        plt.show()
        
        
        
#         hard.append(grad)
#     elif l == 'MI':
#         mild.append(grad)
#     elif l == 'SO':
#         soft.append(grad)

# %%
weights = np.ones(5) / 5
file = open("../gear_user_data/thisum_raw_data.txt","r")
lines = file.readlines()
for line in lines:
    [l,d] = line.split(":")
    d = d.replace('[', '').replace(']', '').replace('\n', '')
    d = np.fromstring(d, dtype=int, sep=',')
    data = np.convolve(d, weights, mode='valid')
    x = np.arange(data.size)
    grad = np.gradient(data, x)
    grad2 = np.gradient(grad, x)
    print()
    print(data)
    print(grad)
#     l = l.split("-")[1]
#     print(grad.argmin())
